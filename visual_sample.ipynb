# %%
import matplotlib.pyplot as plt
import matplotlib.dates as dt
import pandas as pd
# %matplotlib inline

import numpy as np

# %matplotlib inline

# %%
df = pd.read_excel('sample.xlsx')

# %%
df
# Out:
#     Unnamed: 0                               Unnamed: 1  Unnamed: 2  \
# 0          NaN                                      NaN         0.0
# 1          NaN                                    すし 京辰         NaN
# 2          NaN                               日本橋海鮮丼　つじ半         NaN
# 3          NaN                         SPROUT Café さくら坂         NaN
# 4          NaN                          THE CITY BAKERY         NaN
# 5          NaN                     スターバックス コーヒー アークヒルズ店         NaN
# 6          NaN                                  HALE海’ｓ         NaN
# 7          NaN                                   金沢かつぞう         NaN
# 8          NaN                               中国名菜 陳麻婆豆腐         NaN
# 9          NaN                                       笑壷         0.0
# 10         NaN                    日本橋天ぷらめし金子半之助　アークヒルズ店         NaN
# 11         NaN                        CRISP SALAD WORKS         NaN
# 12         NaN                              Brianza 6・1         0.0
# ...

# %%
plt.imshow(df, vmin=0, vmax=1, cmap='Blues')
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-c71048ceecba> in <module>
# ----> 1 plt.imshow(df, vmin=0, vmax=1, cmap='Blues')
#       2 plt.colorbar()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2728         filternorm=filternorm, filterrad=filterrad, resample=resample,
#    2729         url=url, **({"data": data} if data is not None else {}),
# -> 2730         **kwargs)
#    2731     sci(__ret)
#    2732     return __ret
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# ...
